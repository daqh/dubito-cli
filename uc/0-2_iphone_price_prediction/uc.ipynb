# %%
# !dubito generate
# !./query.sh
# !./fetch.sh
# !./find.sh

# %%
# !./fetch.sh
# Out:
# [01/10/24 11:49:30] INFO     Fetching                                ]8;id=353468;file:///home/valerio/Documenti/dubito-cli/src/dubito/commands/fetch.py\fetch.py]8;;\:]8;id=333690;file:///home/valerio/Documenti/dubito-cli/src/dubito/commands/fetch.py#11\11]8;;\
#                              https://www.iphoneitalia.com/...
# [01/10/24 11:49:31] CRITICAL [REQUEST FAILED] 404 Client Error:   ]8;id=682352;file:///home/valerio/Documenti/dubito-cli/.venv/lib/python3.10/site-packages/newspaper/network.py\network.py]8;;\:]8;id=390951;file:///home/valerio/Documenti/dubito-cli/.venv/lib/python3.10/site-packages/newspaper/network.py#112\112]8;;\
#                              Not Found for url:
#                              https://www.iphoneitalia.com/rss
# ...
